# %% [markdown]
# # Aula 3 - Seaborn

# %% [markdown]
# Prof. Tiago Dias
#
# [Linkedin](https://www.linkedin.com/in/diasctiago/) | [Github](https://github.com/diasctiago) | [Blog](https://www.dadosaocubo.com/)

# %% [markdown]
# ### Documentações

# %% [markdown]
# [Documentação Seaborn](https://seaborn.pydata.org/tutorial/introduction.html)

# %% [markdown]
# ### Seaborn

# %%
# instalando
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from seaborn) (1.19.5)
# Requirement already satisfied: scipy>=1.0 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from seaborn) (1.5.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (4.33.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.8)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (9.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: typing-extensions in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn) (4.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\w.souza\videos\data analytics\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Could not fetch URL https://pypi.org/simple/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/pip/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1056)'))) - skipping
# WARNING: There was an error checking the latest version of pip.

# %%
# importando a biblioteca
import pandas as pd
import seaborn as sns

# %%
# verificando as base disponíveis no seaborn
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# importando algumas bases de dados
flights = sns.load_dataset('flights')
flights.head(2)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118

# %%
penguins = sns.load_dataset('penguins')
penguins.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
titanic = sns.load_dataset('titanic')
titanic.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %% [markdown]
# #### Gráfico de Barras

# %%
# base de dados titanic
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# qual a média de idade por cidade de embarque?
sns.barplot(data=titanic, x='embark_town', y='age');

# %%
titanic.groupby(['embark_town']).mean()
# Out:
#              survived    pclass        age     sibsp     parch       fare  \
# embark_town
# Cherbourg    0.553571  1.886905  30.814769  0.386905  0.363095  59.954144
# Queenstown   0.389610  2.909091  28.089286  0.428571  0.168831  13.276030
# Southampton  0.336957  2.350932  29.445397  0.571429  0.413043  27.079812
#
#              adult_male     alone
# embark_town
# Cherbourg      0.535714  0.505952
# Queenstown     0.480519  0.740260
# Southampton    0.636646  0.610248

# %%
# Qual a soma das tarifas por cidades de embarque?
sns.barplot(data=titanic, x='embark_town', y='fare', estimator=sum);

# %%
# Qual a quantidade de pessoas por cidades de embarque?
sns.countplot(data=titanic, x='embark_town');

# %%
titanic['embark_town'].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
# Qual a a quantidade de pessoas por cidades de embarque, separando por sexo?
sns.countplot(data=titanic, x='embark_town', hue='sex');

# %%
# colocando o rótulo das colunas no gráfico acima
g1 = sns.countplot(data=titanic, x='embark_town', hue='sex')
for barra in g1.patches:
  print(barra)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.4, height=441, angle=0)
# Rectangle(xy=(0.6, 0), width=0.4, height=95, angle=0)
# Rectangle(xy=(1.6, 0), width=0.4, height=41, angle=0)
# Rectangle(xy=(-2.77556e-17, 0), width=0.4, height=203, angle=0)
# Rectangle(xy=(1, 0), width=0.4, height=73, angle=0)
# Rectangle(xy=(2, 0), width=0.4, height=36, angle=0)

# %%
# colocando o rótulo das colunas no gráfico acima
g1 = sns.countplot(data=titanic, x='embark_town', hue='sex')
for barra in g1.patches:
  g1.annotate(barra.get_height(),
              (barra.get_x()+barra.get_width()/2, barra.get_height()+3),
              ha='center')

# %% [markdown]
# #### Gráfico de Linhas

# %%
# base de dados flights
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Qual a média de passageiros por ano?
sns.lineplot(x='year',y='passengers',data=flights);

# %%
# Qual a quantidade de passageiros por ano?
sns.lineplot(data=flights, x='year', y='passengers', estimator=sum);

# %%
# Qual a quantidade de passageiros por ano, separando por mês?
sns.lineplot(data=flights, 
             x='year', 
             y='passengers', 
             estimator=sum,
             hue='month');

# %%
# Colocando estilo no gráfico acima
flights_filter = flights.query('month in ("Jan","Feb","Mar")')
sns.lineplot(data=flights_filter, 
             x='year', 
             y='passengers', 
             estimator=sum,
             hue='month',
             style='month');

# %% [markdown]
# #### Gráfico de Caixa

# %%
# base de dados titanic
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Temos outliers nas idades dos passageiros?
sns.boxplot(data=titanic, x='age');

# %%
sns.boxplot(data=titanic, y='age');

# %%
# Separando por classes, temos outliers nas idades dos passageiros?
sns.boxplot(data=titanic, x='age', y='class');

# %%
# Separando por sexo, temos outliers nas idades dos passageiros?
sns.boxplot(data=titanic, x='age', y='sex');

# %%
sns.boxplot(data=titanic, y='age', x='sex');

# %% [markdown]
# #### Gráfico de Dispersão

# %%
# base de dados pinguins
penguins.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
# observando a relação entre o tamanho e a altura dos bicos dos pinguins
sns.scatterplot(data=penguins,
                x='bill_length_mm',
                y='bill_depth_mm');

# %%
# observando a relação entre o tamanho e a altura dos bicos dos pinguins, detalhando o sexo
sns.scatterplot(data=penguins,
                x='bill_length_mm',
                y='bill_depth_mm',
                hue='sex');

# %%
sns.scatterplot(data=penguins,
                x='bill_length_mm',
                y='bill_depth_mm',
                hue='island');

# %%
sns.scatterplot(data=penguins,
                x='bill_length_mm',
                y='bill_depth_mm',
                hue='species');

# %%
# colocando um estilo nas observações
sns.scatterplot(data=penguins,
                x='bill_length_mm',
                y='bill_depth_mm',
                hue='species',
                style='species');

# %%
sns.scatterplot(data=penguins,
                x='bill_length_mm',
                y='bill_depth_mm',
                hue='species',
                style='sex');

# %%
# Observando a relação entre tamanho do bico, 
# altura do bico, tamanho da nadadeira e peso dos pinguins.
sns.pairplot(penguins,hue='sex');

# %%
sns.pairplot(penguins,hue='species');

# %% [markdown]
# #### Gráfico Mapa de Calor

# %%
# base de dados pinguins
penguins.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
# função de correlação
penguins.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
# Como verificar a correção das variáveis de forma gráfica?
sns.heatmap(penguins.corr());

# %%
# acrescentando mais detalhes ao mapa de calor
sns.heatmap(penguins.corr(), annot=True);

# %%
# alterando as cores do mapa de calor
sns.heatmap(penguins.corr(), annot=True, cmap="YlGnBu");

# %% [markdown]
# ### Atividade

# %% [markdown]
# Resolver as questões abaixo. Em seguida, criar um repositório público no GitHub e armazenar no notebook criado, enviando somente o link do NOTEBOOK para o [Formulário](https://docs.google.com/forms/d/e/1FAIpQLSeahbxqxAmgtt2p_gB9V64XbPnScFoCIYzt3dGFj6uZ5MoW4Q/viewform?usp=sf_link).

# %% [markdown]
# Para resolver as questões abaixo utilizar o dataset [tips](https://github.com/mwaskom/seaborn-data/blob/master/tips.csv).

# %%
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# #### Questão 1

# %% [markdown]
# Qual o valor médio da gorjeta de acordo com o dia da semana?

# %%
sns.barplot(data=tips, x='day', y='tip');

# %% [markdown]
# #### Questão 2

# %% [markdown]
# Qual a soma das gorjetas por turno do dia, observando os fumantes e não fumantes?

# %%
sns.barplot(data=tips, x='time', y='tip',  hue='smoker' , estimator=sum);

# %% [markdown]
# #### Questão 3

# %% [markdown]
# Crie uma coluna calculada com o valor da gorjeta por pessoa. Em seguida crie dois gráficos, um com o valor médio da gorjeta de acordo com a quantidade de pessoas da conta e outro com o valor médio da gorjeta individual também de acordo com a quantidade de pessoas da conta.

# %%
tips['por_pessoas'] = tips['tip'] / tips['size']

# %%
sns.barplot(data=tips, x='size', y='tip');

# %%
sns.barplot(data=tips, x='size', y='por_pessoas');

# %% [markdown]
# #### Questão 4

# %% [markdown]
# Qual a relação do valor total da conta com o valor da gorjeta?

# %%
sns.scatterplot(data=tips,
                x='total_bill',
                y='tip');

# %% [markdown]
# #### Questão 5

# %% [markdown]
# Qual público dá maior quantidade de gorjetas:
#
#
# 1.   Homens ou mulheres?
# 2.   Fumantes ou não fumantes?

# %%
# Homens ou mulheres?

sns.barplot(data=tips, x='sex', y='tip' , estimator=sum);

# %%
sns.barplot(data=tips, x='smoker', y='tip' , estimator=sum);

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  por_pessoas
# 0       16.99  1.01  Female     No  Sun  Dinner     2     0.505000
# 1       10.34  1.66    Male     No  Sun  Dinner     3     0.553333
# 2       21.01  3.50    Male     No  Sun  Dinner     3     1.166667

# %% [markdown]
# #### Questão 6

# %% [markdown]
# Quando temos a maior e a menor soma de gorjetas:
#
#
# 1.   Qual dia da semana?
# 2.   Qual turno do dia?

# %%
sns.barplot(data=tips, x='day', y='tip' , estimator=sum);

# %%
sns.barplot(data=tips, x='time', y='tip' , estimator=sum);
